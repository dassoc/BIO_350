# %% [markdown]
# plotting raw data from study

# %%
#plotting species_distribution_data from study to visualize trends
import seaborn as sns

sns.boxplot(x="Site", y="Abundance", data=data)
plt.title("Abundance by Site")
plt.show()

# %%
import matplotlib.pyplot as plt

plt.scatter(data["Abundance"], data["Biomass_g"])
plt.xlabel("Abundance")
plt.ylabel("Biomass (g)")
plt.title("Abundance vs Biomass")
plt.show()

# %%
plt.hist(data["Abundance"], bins=15, edgecolor='black')
plt.xlabel("Abundance")
plt.ylabel("Frequency")
plt.title("Distribution of Abundance")
plt.show()

# %%
sns.scatterplot(x="Macroalgae_cover", y="Abundance", data=data)
plt.title("Abundance vs Macroalgae cover")
plt.show()
